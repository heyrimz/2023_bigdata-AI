# %% [markdown]
# <a href="https://colab.research.google.com/github/heyrimz/2023_bigdata-AI/blob/main/230410_6%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_temp = pd.read_csv("/content/drive/MyDrive/빅데이터와 인공지능/graph.csv",header=None)   # road_data
df_temp.head()
# Out:
#       0             1          2
# 0  Year  No_Smoothing  Lowess(5)
# 1  1880         -0.17      -0.09
# 2  1881         -0.08      -0.13
# 3  1882         -0.11      -0.17
# 4  1883         -0.17       -0.2

# %%
df_temp = df_temp.iloc[1:] # 0행 삭제

# %%
df_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 143 entries, 1 to 143
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       143 non-null    object
#  1   1       143 non-null    object
#  2   2       143 non-null    object
# dtypes: object(3)
# memory usage: 3.5+ KB

# %%
df_temp
# Out:
#         0      1      2
# 1    1880  -0.17  -0.09
# 2    1881  -0.08  -0.13
# 3    1882  -0.11  -0.17
# 4    1883  -0.17   -0.2
# 5    1884  -0.28  -0.24
# ..    ...    ...    ...
# 139  2018   0.84   0.93
# 140  2019   0.98   0.92
# 141  2020   1.02   0.92
# 142  2021   0.85   0.91
# 143  2022   0.89   0.91
#
# [143 rows x 3 columns]

# %%
df_gdp = pd.read_csv("/content/drive/MyDrive/빅데이터와 인공지능/API_NY.GDP.MKTP.CD_DS2_en_csv_v2_5358352.csv")
df_gdp.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.CD  2.129150e+10  2.180940e+10  2.370810e+10  2.821130e+10
# 2  NY.GDP.MKTP.CD  5.377778e+08  5.488889e+08  5.466667e+08  7.511112e+08
# 3  NY.GDP.MKTP.CD  1.040410e+10  1.112790e+10  1.194320e+10  1.267630e+10
# 4  NY.GDP.MKTP.CD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2012          2013          2014  \
# ...

# %%
df_gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 66 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            134 non-null    float64
#  5   1961            136 non-null    float64
#  6   1962            138 non-null    float64
#  7   1963            138 non-null    float64
#  8   1964            138 non-null    float64
#  9   1965            149 non-null    float64
#  10  1966            152 non-null    float64
#  11  1967            155 non-null    float64
#  12  1968            160 non-null    float64
#  13  1969            160 non-null    float64
#  14  1970            169 non-null    float64
#  15  1971            172 non-null    float64
#  16  1972            172 non-null    float64
# ...

# %%
df_gdp = df_gdp.sum(axis = 0) 
print(df_gdp)
# Out:
# Country Name      ArubaAfrica Eastern and SouthernAfghanistanAfr...
# Country Code      ABWAFEAFGAFWAGOALBANDARBAREARGARMASMATGAUSAUTA...
# Indicator Name    GDP (current US$)GDP (current US$)GDP (current...
# Indicator Code    NY.GDP.MKTP.CDNY.GDP.MKTP.CDNY.GDP.MKTP.CDNY.G...
# 1960                                           9518432021034.720703
#                                         ...
# 2017                                             673319593022841.75
# 2018                                            715369906175107.875
# 2019                                              725547439367939.0
# 2020                                             703154445622073.75
# 2021                                             802770879405363.75
# Length: 66, dtype: object

# %%
df_gdp = df_gdp.iloc[4:]

# %%
df_gdp
# Out:
# 1960     9518432021034.720703
# 1961     9773783201397.189453
# 1962    10418785097216.972656
# 1963    11239384846406.808594
# 1964    12339126712292.759766
#                 ...
# 2017       673319593022841.75
# 2018      715369906175107.875
# 2019        725547439367939.0
# 2020       703154445622073.75
# 2021       802770879405363.75
# Length: 62, dtype: object

# %%
df_gdp = pd.DataFrame(df_gdp)
df_gdp
# Out:
#                           0
# 1960   9518432021034.720703
# 1961   9773783201397.189453
# 1962  10418785097216.972656
# 1963  11239384846406.808594
# 1964  12339126712292.759766
# ...                     ...
# 2017     673319593022841.75
# 2018    715369906175107.875
# 2019      725547439367939.0
# 2020     703154445622073.75
# 2021     802770879405363.75
#
# [62 rows x 1 columns]

# %%
df_temp.columns=["year","tmp1","tmp2"]
df_temp = df_temp.set_index("year")

# %%
df_temp
# Out:
#        tmp1   tmp2
# year
# 1880  -0.17  -0.09
# 1881  -0.08  -0.13
# 1882  -0.11  -0.17
# 1883  -0.17   -0.2
# 1884  -0.28  -0.24
# ...     ...    ...
# 2018   0.84   0.93
# 2019   0.98   0.92
# 2020   1.02   0.92
# 2021   0.85   0.91
# 2022   0.89   0.91
#
# [143 rows x 2 columns]

# %%
temp_gdp = pd.concat([df_temp,df_gdp],axis = 1)
print(temp_gdp)
# Out:
#        tmp1   tmp2                    0
# 1880  -0.17  -0.09                  NaN
# 1881  -0.08  -0.13                  NaN
# 1882  -0.11  -0.17                  NaN
# 1883  -0.17   -0.2                  NaN
# 1884  -0.28  -0.24                  NaN
# ...     ...    ...                  ...
# 2018   0.84   0.93  715369906175107.875
# 2019   0.98   0.92    725547439367939.0
# 2020   1.02   0.92   703154445622073.75
# 2021   0.85   0.91   802770879405363.75
# 2022   0.89   0.91                  NaN
#
# [143 rows x 3 columns]

# %%
final_temp_gdp = temp_gdp.dropna(axis = 0) 
print(final_temp_gdp)
# Out:
#        tmp1   tmp2                      0
# 1960  -0.03   0.03   9518432021034.720703
# 1961   0.06   0.01   9773783201397.189453
# 1962   0.03  -0.01  10418785097216.972656
# 1963   0.05  -0.03  11239384846406.808594
# 1964   -0.2  -0.04  12339126712292.759766
# ...     ...    ...                    ...
# 2017   0.92   0.91     673319593022841.75
# 2018   0.84   0.93    715369906175107.875
# 2019   0.98   0.92      725547439367939.0
# 2020   1.02   0.92     703154445622073.75
# 2021   0.85   0.91     802770879405363.75
#
# [62 rows x 3 columns]
